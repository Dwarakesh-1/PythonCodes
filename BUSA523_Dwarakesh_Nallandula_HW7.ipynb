# %%
import pandas as pd

dataframe = pd.read_csv('Stocks.csv',index_col = 'Symbol')

dataframe
# Out:
#                          Company Exchange                        Industry  \
# Symbol
# MMM                           3M     NYSE                    Conglomerate
# AXP             American Express     NYSE              Financial services
# AMGN                       Amgen   NASDAQ         Pharmaceutical industry
# AAPL                  Apple Inc.   NASDAQ          Information technology
# BA                        Boeing     NYSE           Aerospace and defense
# CAT             Caterpillar Inc.     NYSE         Construction and Mining
# CVX          Chevron Corporation     NYSE              Petroleum industry
# CSCO               Cisco Systems   NASDAQ          Information technology
# KO         The Coca-Cola Company     NYSE                   Food industry
# DOW                     Dow Inc.     NYSE               Chemical industry
# GS                 Goldman Sachs     NYSE              Financial services
# HD                The Home Depot     NYSE                       Retailing
# ...

# %%
#How many non-null values exist for each column and what each column’s type is

dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, MMM to DIS
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          30 non-null     object
#  1   Exchange         30 non-null     object
#  2   Industry         30 non-null     object
#  3   Date added       30 non-null     object
#  4   Notes            4 non-null      object
#  5   Index weighting  30 non-null     object
# dtypes: object(6)
# memory usage: 1.6+ KB

# %%
#Utilizing the len( ) function

len(dataframe)
# Out:
# 30

# %%
#Utilizing the shape property

dataframe.shape
# Out:
# (30, 6)

# %%
#first 10 rows

dataframe.head(10)
# Out:
#                       Company Exchange                 Industry  Date added  \
# Symbol
# MMM                        3M     NYSE             Conglomerate  1976-08-09
# AXP          American Express     NYSE       Financial services  1982-08-30
# AMGN                    Amgen   NASDAQ  Pharmaceutical industry  2020-08-31
# AAPL               Apple Inc.   NASDAQ   Information technology  2015-03-19
# BA                     Boeing     NYSE    Aerospace and defense  1987-03-12
# CAT          Caterpillar Inc.     NYSE  Construction and Mining  1991-05-06
# CVX       Chevron Corporation     NYSE       Petroleum industry  2008-02-19
# CSCO            Cisco Systems   NASDAQ   Information technology  2009-06-08
# KO      The Coca-Cola Company     NYSE            Food industry  1987-03-12
# DOW                  Dow Inc.     NYSE        Chemical industry  2019-04-02
#
#                                         Notes Index weighting
# Symbol
# ...

# %%
#last 10 rows

dataframe.tail(10)
# Out:
#                          Company Exchange                        Industry  \
# Symbol
# NKE                   Nike, Inc.     NYSE                         Apparel
# PG              Procter & Gamble     NYSE      Fast-moving consumer goods
# CRM                   Salesforce     NYSE          Information technology
# TRV      The Travelers Companies     NYSE              Financial services
# UNH           UnitedHealth Group     NYSE             Managed health care
# VZ        Verizon Communications     NYSE               Telecommunication
# V                      Visa Inc.     NYSE              Financial services
# WBA     Walgreens Boots Alliance   NASDAQ                       Retailing
# WMT                      Walmart     NYSE                       Retailing
# DIS      The Walt Disney Company     NYSE  Broadcasting and entertainment
#
#         Date added Notes Index weighting
# Symbol
# NKE     2013-09-20   NaN           2.58%
# PG      1932-05-26   NaN           2.64%
# ...

# %%
#Show the Company column

dataframe['Company']
# Out:
# Symbol
# MMM                           3M
# AXP             American Express
# AMGN                       Amgen
# AAPL                  Apple Inc.
# BA                        Boeing
# CAT             Caterpillar Inc.
# CVX          Chevron Corporation
# CSCO               Cisco Systems
# KO         The Coca-Cola Company
# DOW                     Dow Inc.
# GS                 Goldman Sachs
# HD                The Home Depot
# HON                    Honeywell
# IBM                          IBM
# INTC                       Intel
# JNJ            Johnson & Johnson
# JPM               JPMorgan Chase
# MCD                   McDonald's
# MRK                  Merck & Co.
# MSFT                   Microsoft
# NKE                   Nike, Inc.
# PG              Procter & Gamble
# CRM                   Salesforce
# TRV      The Travelers Companies
# UNH           UnitedHealth Group
# VZ        Verizon Communications
# V                      Visa Inc.
# WBA     Walgreens Boots Alliance
# ...

# %%
#Show the columns named Company and Industry in a DataFrame

dataframe[['Company','Industry']]
# Out:
#                          Company                        Industry
# Symbol
# MMM                           3M                    Conglomerate
# AXP             American Express              Financial services
# AMGN                       Amgen         Pharmaceutical industry
# AAPL                  Apple Inc.          Information technology
# BA                        Boeing           Aerospace and defense
# CAT             Caterpillar Inc.         Construction and Mining
# CVX          Chevron Corporation              Petroleum industry
# CSCO               Cisco Systems          Information technology
# KO         The Coca-Cola Company                   Food industry
# DOW                     Dow Inc.               Chemical industry
# GS                 Goldman Sachs              Financial services
# HD                The Home Depot                       Retailing
# HON                    Honeywell                    Conglomerate
# ...

# %%
#Present the information for the row that has the symbol AAPL

dataframe.loc['AAPL']
# Out:
# Company                        Apple Inc.
# Exchange                           NASDAQ
# Industry           Information technology
# Date added                     2015-03-19
# Notes                                 NaN
# Index weighting                     2.57%
# Name: AAPL, dtype: object

# %%
#Show the Exchange for the row with the Symbol AAPL

dataframe.loc['AAPL']['Exchange']
# Out:
# 'NASDAQ'

# %%
#Sort (and show) the data by Industry, then Company

dataframe.sort_values(['Industry','Company'], ascending = False)
# Out:
#                          Company Exchange                        Industry  \
# Symbol
# VZ        Verizon Communications     NYSE               Telecommunication
# WMT                      Walmart     NYSE                       Retailing
# WBA     Walgreens Boots Alliance   NASDAQ                       Retailing
# HD                The Home Depot     NYSE                       Retailing
# MRK                  Merck & Co.     NYSE         Pharmaceutical industry
# JNJ            Johnson & Johnson     NYSE         Pharmaceutical industry
# AMGN                       Amgen   NASDAQ         Pharmaceutical industry
# CVX          Chevron Corporation     NYSE              Petroleum industry
# UNH           UnitedHealth Group     NYSE             Managed health care
# CRM                   Salesforce     NYSE          Information technology
# MSFT                   Microsoft   NASDAQ          Information technology
# INTC                       Intel   NASDAQ          Information technology
# ...

# %%
#Show the rows where Industry is Information Technology

dataframe[dataframe.Industry == 'Information technology']
# Out:
#               Company Exchange                Industry  Date added  \
# Symbol
# AAPL       Apple Inc.   NASDAQ  Information technology  2015-03-19
# CSCO    Cisco Systems   NASDAQ  Information technology  2009-06-08
# IBM               IBM     NYSE  Information technology  1979-06-29
# INTC            Intel   NASDAQ  Information technology  1999-11-01
# MSFT        Microsoft   NASDAQ  Information technology  1999-11-01
# CRM        Salesforce     NYSE  Information technology  2020-08-31
#
#                                 Notes Index weighting
# Symbol
# AAPL                              NaN           2.57%
# CSCO                              NaN           1.00%
# IBM     Also 1932-05-26 to 1939-03-04           2.59%
# INTC                              NaN           1.25%
# MSFT                              NaN           4.98%
# CRM                               NaN           4.45%

# %%
#Show the rows where Notes has a value (other than missing)

dataframe[dataframe.Notes.notna()]
# Out:
#                       Company Exchange                Industry  Date added  \
# Symbol
# MMM                        3M     NYSE            Conglomerate  1976-08-09
# CVX       Chevron Corporation     NYSE      Petroleum industry  2008-02-19
# KO      The Coca-Cola Company     NYSE           Food industry  1987-03-12
# IBM                       IBM     NYSE  Information technology  1979-06-29
#
#                                         Notes Index weighting
# Symbol
# MMM     As Minnesota Mining and Manufacturing           3.84%
# CVX             Also 1930-07-18 to 1999-11-01           2.03%
# KO              Also 1932-05-26 to 1935-11-20           1.04%
# IBM             Also 1932-05-26 to 1939-03-04           2.59%

# %%
#Create and display a DataFrame from the full DataFrame but excluding the Notes column

dataframe.drop('Notes', axis = 'columns', inplace = True) 
dataframe
# Out:
#                          Company Exchange                        Industry  \
# Symbol
# MMM                           3M     NYSE                    Conglomerate
# AXP             American Express     NYSE              Financial services
# AMGN                       Amgen   NASDAQ         Pharmaceutical industry
# AAPL                  Apple Inc.   NASDAQ          Information technology
# BA                        Boeing     NYSE           Aerospace and defense
# CAT             Caterpillar Inc.     NYSE         Construction and Mining
# CVX          Chevron Corporation     NYSE              Petroleum industry
# CSCO               Cisco Systems   NASDAQ          Information technology
# KO         The Coca-Cola Company     NYSE                   Food industry
# DOW                     Dow Inc.     NYSE               Chemical industry
# GS                 Goldman Sachs     NYSE              Financial services
# HD                The Home Depot     NYSE                       Retailing
# ...

# %%
dataframe1 = pd.read_csv('Stock-Prices.csv', index_col = 'Symbol')
dataframe1
# Out:
#          Price
# Symbol
# MMM     223.34
# AXP     176.22
# AMGN    262.12
# AAPL    137.07
# BA      271.76
# CAT     265.12
# CVX     114.33
# CSCO     58.23
# KO       60.89
# DOW      75.30
# GS      409.46
# HD      350.93
# HON     254.53
# IBM     158.39
# INTC     62.89
# JNJ     186.34
# JPM     180.62
# MCD     257.24
# MRK      14.08
# MSFT    274.81
# NKE     150.11
# PG      148.39
# CRM     261.25
# TRV     175.67
# UNH     453.73
# VZ       62.15
# V       250.25
# WBA      58.03
# WMT     156.22
# DIS     196.66

# %%
#Use join() to augment the DataFrame with the Price data

dataframe.join(dataframe1)
# Out:
#                          Company Exchange                        Industry  \
# Symbol
# MMM                           3M     NYSE                    Conglomerate
# AXP             American Express     NYSE              Financial services
# AMGN                       Amgen   NASDAQ         Pharmaceutical industry
# AAPL                  Apple Inc.   NASDAQ          Information technology
# BA                        Boeing     NYSE           Aerospace and defense
# CAT             Caterpillar Inc.     NYSE         Construction and Mining
# CVX          Chevron Corporation     NYSE              Petroleum industry
# CSCO               Cisco Systems   NASDAQ          Information technology
# KO         The Coca-Cola Company     NYSE                   Food industry
# DOW                     Dow Inc.     NYSE               Chemical industry
# GS                 Goldman Sachs     NYSE              Financial services
# HD                The Home Depot     NYSE                       Retailing
# ...
