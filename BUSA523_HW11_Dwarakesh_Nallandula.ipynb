# %%
#Defining the class
class Address:
    #constructor with apartment number
    def __init__(self, apart_num):
        self.apartnum = apart_num
    #set house number
    def setHousenum(self, house):
        self.housenum = house
    #set street name
    def setStreet(self, street):
        self.streetname = c street
    #set zip code
    def setZipcode(self, zipc):
        self.zipcode = zipc
    #set city name
    def setCity(self, city):
        self.cityname = city
    #set state name
    def setState(self, state):
        self.statename = state
    #defining print method
    def printing(self):
        #condition to check whether the apartment number is null or not
        if self.apartnum == "":
            print(f"The house number is {self.housenum}, the street is {self.streetname} and the appartment number is N/A")
            print(f"The city is {self.cityname}, the state is {self.statename} and the zip code is {self.zipcode}")
        else:
            print(f"The house number is {self.housenum}, the street is {self.streetname} and the appartment number is {self.apartnum}")
            print(f"The city is {self.cityname}, the state is {self.statename} and the zip code is {self.zipcode}")
    #defining comes before
    def comesBefore(self, other):
        firstzip = self.zipcode     #getting zipcode of self
        secondzip = other.zipcode   #getting zipcode of other
        
        #comparing the zip codes
        if firstzip > secondzip:
            print("The other address comes before the first!!")
        elif firstzip < secondzip:
            print("The first address comes before the other!!")
        else:
            print("Both address are on the same zipcode!!")
            

#providing first address
first_address = Address(input(("Enter the apartment number(if available): ")))
first_address.setHousenum(int(input("Enter the house number: ")))
first_address.setStreet(input("Enter the street name: "))
first_address.setZipcode(int(input("Enter the zip code: ")))
first_address.setCity(input("Enter the name of the city: "))
first_address.setState(input("Enter the name of the state: "))
print()
first_address.printing()

#for new line to provide space between each data
print()

#providing second address
second_address = Address(input(("Enter the apartment number(if available): ")))
second_address.setHousenum(int(input("Enter the house number: ")))
second_address.setStreet(input("Enter the street name: "))
second_address.setZipcode(int(input("Enter the zip code: ")))
second_address.setCity(input("Enter the name of the city: "))
second_address.setState(input("Enter the name of the state: "))
print()
second_address.printing()

#for new line to provide space between each data
print()
first_address.comesBefore(second_address)
# Out:
# Enter the apartment number(if available):
# Enter the house number: 2604
# Enter the street name: Taylor St
# Enter the zip code: 75428
# Enter the name of the city: Co
# Enter the name of the state: Tx
#
# The house number is 2604, the street is Taylor St and the appartment number is N/A
# The city is Co, the state is Tx and the zip code is 75428
#
# Enter the apartment number(if available): 2468
# Enter the house number: 2231
# Enter the street name: Live Oak St
# Enter the zip code: 75428
# Enter the name of the city: Co
# Enter the name of the state: Tx
#
# The house number is 2231, the street is Live Oak St and the appartment number is 2468
# The city is Co, the state is Tx and the zip code is 75428
#
# Both address are on the same zipcode!!
